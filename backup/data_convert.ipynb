# %%
# !source .venv/bin/activate

# %%
# %pip install xarray
# %pip install netCDF4 h5netcdf
# %pip install cftime

# %%
# !python -c "import netCDF4, h5netcdf, xarray; print('OK')"
# Out:
# OK

# %%
import xarray as xr

ds = xr.open_dataset(
    "era5_ssrd_5am_7pm_IST_2024/Solar_Site_01_2024_04_ssrd_gridded_9km_IST_5am-7pm.nc",
    engine="netcdf4"
)

print(ds)
# Out:
# <xarray.Dataset>
# Dimensions:    (time: 420, latitude: 5, longitude: 5)
# Coordinates:
#     number     int64 ...
#     expver     (time) object ...
#   * latitude   (latitude) float64 8.978 9.059 9.14 9.221 9.302
#   * longitude  (longitude) float64 77.76 77.84 77.92 78.0 78.08
#   * time       (time) datetime64[ns] 2024-04-01T05:30:00 ... 2024-04-30T18:30:00
# Data variables:
#     ssrd       (time, latitude, longitude) float64 ...
# Attributes:
#     GRIB_centre:             ecmf
#     GRIB_centreDescription:  European Centre for Medium-Range Weather Forecasts
#     GRIB_subCentre:          0
#     Conventions:             CF-1.7
#     institution:             European Centre for Medium-Range Weather Forecasts
#     history:                 2026-02-04T11:09 GRIB to CDM+CF via cfgrib-0.9.1...
